# %%
## 导入模型和设置
import os
model_path = 'ckpt-set/ckpt-EDFA-2stps/'
os.system(f'cp {model_path}config.py config.py')
import config
import torch
import numpy as np
import matplotlib.pyplot as plt
import config
from fiber_system import tx,rx,channel_model
from train_model import test_model, get_model
fig_path =  '/Users/xinyu/Desktop/WDM_Code/report/img/expriment/'  # 储存结果的路径

# %%
############################ setting parameters ############################
test_power = 1
############################ Initializing the system ############################
k = config.k              # number of central channel
tx.set_power([test_power]*config.Nch)
rx.set_power([test_power]*config.Nch)
comp = {}
z = {}
I = {}

############################ load model     ############################
model_names = ['no comp','full DBP', 'DO-DBP', 'SC-DBP','NN-DBP','Meta-1','Meta-2','Meta-3']

for name in model_names:
    comp[name] = get_model(name, model_path)

############################ simulation and testing    ############################

'''               communication system structure
    ----------------------         -------------          ----------                
x --|      (1)Fiber        |-- y --|  (2)DBP     |-- z --| (3)Filter | --- I --- (4) show constellation
     ----------------------         -------------          ---------
'''

# (1) Fiber
x, symbol_stream, bit_stream = tx.wdm_signal_sample()
x = x.cuda()
channel_model = channel_model.cuda()
y = channel_model(x)

# (2) DBP
for name in model_names:s
    if name == 'full DBP':
        z[name] = comp[name](y)[k]
    else:
        z[name] = comp[name](y)[0]


# (3) Filter 
for name in model_names:
    I[name] = rx.filter(z[name], Nch=k)

# (4) show constellation
plt.figure(figsize=(16,8))
for i,name in enumerate(model_names):
    plt.subplot(241+i)
    rx.show_symbol(I[name], symbol_stream[k])
    plt.title(name)
#plt.savefig(fig_path + f'W120-D3-P{power}'+'star.png')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-88a63263b156> in <module>()
#      35         z[name] = comp[name](y)[k]
#      36     else:
# ---> 37         z[name] = comp[name](y)[0]
#      38
#      39
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/optic_simulation/Fiber.py in forward(self, u)
#     252
#     253     def forward(self,u):
# --> 254         return torch.index_select(u, dim=-2, index=torch.tensor([config.k]))
#
# RuntimeError: Input, output and indices must be on the current device

# %%
comp
# Out:
# {'no comp': WSS(), 'full DBP': Sequential(
#    (0): Sequential(
#      (full DBP 0): Fiber()
#      (full DBP 1): Fiber()
#      (full DBP 2): Fiber()
#      (full DBP 3): Fiber()
#      (full DBP 4): Fiber()
#      (full DBP 5): Fiber()
#      (full DBP 6): Fiber()
#      (full DBP 7): Fiber()
#      (full DBP 8): Fiber()
#      (full DBP 9): Fiber()
#    )
#  ), 'DO-DBP': Sequential(
#    (0): WSS()
#    (1): Sequential(
#      (CD 0): Fiber()
#      (CD 1): Fiber()
#      (CD 2): Fiber()
#      (CD 3): Fiber()
#      (CD 4): Fiber()
#      (CD 5): Fiber()
#      (CD 6): Fiber()
#      (CD 7): Fiber()
#      (CD 8): Fiber()
#      (CD 9): Fiber()
#    )
#  ), 'SC-DBP': Sequential(
#    (0): WSS()
#    (1): Sequential(
#      (SC-DBP 0): Fiber()
#      (SC-DBP 1): Fiber()
#      (SC-DBP 2): Fiber()
#      (SC-DBP 3): Fiber()
#      (SC-DBP 4): Fiber()
#      (SC-DBP 5): Fiber()
#      (SC-DBP 6): Fiber()
#      (SC-DBP 7): Fiber()
#      (SC-DBP 8): Fiber()
#      (SC-DBP 9): Fiber()
#    )
#  ), 'NN-DBP': Sequential(
#    (0): WSS()
#    (1): Sequential(
#      (DBP Block 0): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 1): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 2): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 3): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 4): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 5): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 6): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 7): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 8): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#      (DBP Block 9): Fiber(
#        (H_trained): ParameterList(
#            (0): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.ComplexFloatTensor of size 1x1024 (GPU 0)]
#        )
#        (scales): ParameterList(
#            (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#            (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#        )
#      )
#    )
#  ), 'Meta-1': Sequential(
#    (0): WSS()
#    (1): Sequential(
#      (DBP Block 0): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 1): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 2): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 3): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 4): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 5): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 6): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 7): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 8): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 9): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (other_channel): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#    )
#  ), 'Meta-2': Sequential(
#    (0): WSS()
#    (1): Sequential(
#      (DBP Block 0): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 1): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 2): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 3): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 4): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 5): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 6): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 7): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 8): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#      (DBP Block 9): Fiber(
#        (H_trained): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#        (scales): ModuleList(
#          (0): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#          (1): FNN(
#            (fc0): complex_linear()
#            (net): ModuleList(
#              (0): complex_linear()
#              (1): complex_linear()
#              (2): complex_linear()
#            )
#            (fc1): complex_linear()
#          )
#        )
#      )
#    )
#  ), 'Meta-3': Sequential(
#    (0): WSS()
#    (1): Sequential(
#      (DBP Block 0): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 1): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 2): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 3): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 4): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 5): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 6): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 7): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 8): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#      (DBP Block 9): Fiber(
#        (H_trained): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#        (other_channel): FNN(
#          (fc0): complex_linear()
#          (net): ModuleList(
#            (0): complex_linear()
#            (1): complex_linear()
#            (2): complex_linear()
#          )
#          (fc1): complex_linear()
#        )
#      )
#    )
#  )}

# %%
# 计算BER
acc = {}
for name in model_names:
    acc[name] = test_model(channel_model, comp[name], tx,rx,N=100,power=50)

for key in acc.keys():
    print('%10s  &   %g \\\\' % (key, acc[key]))
# Out:
#    no comp  &   0.517852 \\
#   full DBP  &   1 \\
#     DO-DBP  &   0.332109 \\
#     SC-DBP  &   0.405 \\
#     NN-DBP  &   0.999453 \\
#     Meta-1  &   1 \\
#     Meta-2  &   1 \\
#     Meta-3  &   0.999961 \\

# %%
channel_model(x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-ccbf013f9e3d> in <module>()
# ----> 1 channel_model(x)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/optic_simulation/Fiber.py in forward(self, u, step)
#     200             temp = u
#     201
# --> 202             u = self.nl_step(u,v,step=step)
#     203             u = self.lin_step(u,v,step=step)
#     204             u = u * np.exp(-0.5 * self.alphalin * self.dz)
#
# ~/optic_simulation/Fiber.py in nl_step(self, u, v, step)
#     181             Normal SSFM nonlinear step
#     182             '''
# --> 183             u = u * torch.exp(-(1j) * self.gam * power * leff)
#     184         return u
#     185
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!

# %%
# plot loss curve
loss = {}
power=50
#for name in train_model_names:
train_model_names = ['NN-DBP','Meta-1','Meta-2','Meta-3']
for name in train_model_names:
    loss[name] = torch.load(model_path + name + '_losspath.pt')['train loss']
    plt.plot(loss[name],label=name)

plt.legend(loc='best')
plt.title('loss curve')
plt.xlabel('epoch')
plt.ylabel('loss')
#plt.savefig(fig_path + f'W120-D3-P{power}'+'loss.png')

# %%
## 待办事项
'''
**1. 可视化参数，看到底是那部分起作用
2. 加宽，加深 网络，或者改变网络架构 （Transformer）
3. 数据增广， 看泛化
4. 学习率策略: 0.001

width: 20,60,100
depth: 2,3,4
power: [50,50], [50,60]
'''

'''
1. meta net 结构调整
(1) complex CNN
(2) complex RNN,Transformer  加入历史信息 S = phi(u_i, u_{i-1})

2.noise term
n  -->  n * u

3. channel num, 16 QAM

'''

# %%
'''
'scale', 'plus', 'scale+plus' 为什么会相同的loss曲线
'''
fiber = Fiber(tx.lam_set,length=1e5,alphaB=0.2,n2=2.7e-20,disp=17,dz=100,Nch=config.Nch,generate_noise=True,noise_level=1e-3)
dsp = Fiber(tx.lam_set,length=1e5,alphaB=-0.2,n2=-2.7e-20,disp=-17,dz=200,Nch=config.Nch)
x,s,_ = tx.wdm_signal_sample()

z = x
for i in range(10):
    y = fiber(z)
    z = dsp(y)
I = rx.filter(z[0],Nch=1)
rx.show_symbol(I,s[0])

# %%
a = torch.rand(10,3,100)

# %%
torch.index_select(a,dim=-2,index=torch.tensor([0])).shape
# Out:
# torch.Size([10, 1, 100])

# %%
# Out:
# tensor([1])
